# %% [markdown]
# **Cleaning up data**

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'},
    {'job_title': 'Junior Data Scientist', 'job_skills': "['Python', 'SQL', 'Statistics']", 'job_date': '2023-05-25'},
    {'job_title': 'Data Science Intern', 'job_skills': "['R', 'Python', 'Data Visualization']", 'job_date': '2023-05-26'},
    {'job_title': 'Data Science Manager', 'job_skills': "['Machine Learning', 'Business Strategy', 'Team Management']", 'job_date': '2023-05-24'},
    {'job_title': 'Senior Data Analyst', 'job_skills': "['SQL', 'Python', 'Data Mining']", 'job_date': '2023-05-27'},
    {'job_title': 'Machine Learning Researcher', 'job_skills': "['Python', 'Deep Learning', 'Research Methodology']", 'job_date': '2023-05-29'}
]

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 8, 21, 8, 27, 48, 469762)

# %%
test_date = data_science_jobs[0]['job_date']

# %%
datetime.strptime(test_date, '%Y-%m-%d')
# Out:
# datetime.datetime(2023, 5, 12, 0, 0)

# %%
print(datetime.strptime(test_date, '%Y-%m-%d'))
# Out:
# 2023-05-12 00:00:00

# %%
import ast
#код ниже позволяет переделать типы данных внутри листа в нужные
for job in data_science_jobs:
  job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')
  job['job_skills'] = ast.literal_eval(job['job_skills'])

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Deep Learning'],
#   'job_date': datetime.datetime(2023, 5, 15, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['SQL', 'R', 'Tableau'],
#   'job_date': datetime.datetime(2023, 5, 10, 0, 0)},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': ['SQL', 'PowerBI', 'Data Warehousing'],
#   'job_date': datetime.datetime(2023, 5, 8, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'Spark', 'Hadoop'],
#   'job_date': datetime.datetime(2023, 5, 18, 0, 0)},
#  {'job_title': 'AI Specialist',
#   'job_skills': ['Python', 'PyTorch', 'AI Ethics'],
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)},
#  {'job_title': 'Junior Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Statistics'],
#   'job_date': datetime.datetime(2023, 5, 25, 0, 0)},
#  {'job_title': 'Data Science Intern',
#   'job_skills': ['R', 'Python', 'Data Visualization'],
#   'job_date': datetime.datetime(2023, 5, 26, 0, 0)},
#  {'job_title': 'Data Science Manager',
#   'job_skills': ['Machine Learning', 'Business Strategy', 'Team Management'],
#   'job_date': datetime.datetime(2023, 5, 24, 0, 0)},
#  {'job_title': 'Senior Data Analyst',
#   'job_skills': ['SQL', 'Python', 'Data Mining'],
#   'job_date': datetime.datetime(2023, 5, 27, 0, 0)},
#  {'job_title': 'Machine Learning Researcher',
#   'job_skills': ['Python', 'Deep Learning', 'Research Methodology'],
#   'job_date': datetime.datetime(2023, 5, 29, 0, 0)}]
