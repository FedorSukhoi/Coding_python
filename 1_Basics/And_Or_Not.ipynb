# %% [markdown]
# **And**

# %%
job_from_home = True
job_health_insurance = True

job_from_home and job_health_insurance
# Out:
# True

# %% [markdown]
# **Or**

# %%
job_from_home = True
job_health_insurance = False

job_from_home or job_health_insurance
# Out:
# True

# %% [markdown]
# **Not**

# %%
job_from_home = True
job_health_insurance = False

job_from_home and not job_health_insurance
# Out:
# True
