# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.sample(19, random_state=1)
# Out:
#               job_title_short  \
# 303776          Data Engineer
# 330513  Senior Data Scientist
# 237202         Data Scientist
# 539858          Data Engineer
# 618796         Data Scientist
# 392419   Senior Data Engineer
# 657919           Data Analyst
# 470055       Business Analyst
# 65015          Data Scientist
# 24727           Data Engineer
# 127391          Data Engineer
# 448205          Data Engineer
# 376863           Data Analyst
# 37390          Data Scientist
# 431027           Data Analyst
# 15138            Data Analyst
# 125452           Data Analyst
# 658467          Data Engineer
# 33601            Data Analyst
#
#                                                 job_title  \
# 303776                               Data Center Engineer
# 330513                      Big Data Senior - Remote Work
# 237202                                  Database Engineer
# 539858                                Spark Data Engineer
# 618796                       Environmental Data Scientist
# 392419                               Senior Data Engineer
# 657919                                       Data Analyst
# 470055                                 Contract Analyst I
# 65015                             Data Scientist - Senior
# 24727                                       Data Engineer
# 127391                                      Data Engineer
# 448205                                  AWS Data Engineer
# 376863                                       Data Analyst
# 37390   Clinical Data Specialist, remote - (Job Number...
# 431027                                  Data Analyst Lead
# 15138                                        Data Analyst
# 125452                    Data Analyst Intern (2023 Fall)
# 658467                                 Lead Data Engineer
# 33601                                   Data Office-(H/F)
#
#                                     job_location                job_via  \
# 303776                                 Singapore    via BeBee Singapore
# 330513                          Machala, Ecuador           via Sercanto
# 237202               Hyderabad, Telangana, India           via LinkedIn
# 539858                                  Anywhere               via Dice
# 618796                                  Anywhere               via IMEC
# 392419                           Munich, Germany  via BeBee Deutschland
# 657919                                     Italy              via BeBee
# 470055                    Amsterdam, Netherlands              via BeBee
# 65015                       Colorado Springs, CO    via Relocation Jobs
# 24727                           Barcelona, Spain           via LinkedIn
# 127391  Milan, Metropolitan City of Milan, Italy           via LinkedIn
# 448205                               Chicago, IL             via Indeed
# 376863                                  Virginia     via Leidos Careers
# 37390                                   Anywhere          via Talentify
# 431027                                 Singapore    via BeBee Singapore
# 15138                                 Austin, TX        via Trabajo.org
# 125452                                Dallas, TX       via ZipRecruiter
# 658467               Bengaluru, Karnataka, India           via LinkedIn
# 33601                             Rennes, France              via BeBee
#
#        job_schedule_type  job_work_from_home          search_location  \
# 303776         Full-time               False                Singapore
# 330513         Full-time               False                  Ecuador
# 237202         Full-time               False                    India
# 539858        Contractor                True                    Sudan
# 618796         Full-time                True              Netherlands
# 392419         Full-time               False                  Germany
# 657919              None               False                    Italy
# 470055         Full-time               False              Netherlands
# 65015          Full-time               False     Texas, United States
# 24727          Full-time               False                    Spain
# 127391         Full-time               False                    Italy
# 448205        Contractor               False                    Sudan
# 376863         Full-time               False  Illinois, United States
# 37390          Full-time                True                  Morocco
# 431027         Full-time               False                Singapore
# 15138          Full-time               False     Texas, United States
# 125452        Internship               False     Texas, United States
# 658467         Full-time               False                    India
# 33601          Full-time               False                   France
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 303776 2023-12-26 17:15:09                  False                 False
# 330513 2023-04-16 23:32:33                   True                 False
# 237202 2023-02-16 07:13:26                  False                 False
# 539858 2023-03-24 20:39:11                  False                 False
# 618796 2023-03-07 12:47:28                  False                 False
# 392419 2023-04-18 18:16:09                  False                 False
# 657919 2023-08-09 10:54:04                  False                 False
# 470055 2023-10-09 14:42:48                   True                 False
# 65015  2023-04-14 06:04:00                  False                 False
# 24727  2023-06-05 13:33:27                  False                 False
# 127391 2023-10-16 08:34:38                  False                 False
# 448205 2023-01-13 15:23:03                  False                 False
# 376863 2023-10-19 18:25:04                  False                 False
# 37390  2023-02-02 13:54:12                  False                 False
# 431027 2023-01-22 16:21:31                  False                 False
# 15138  2023-03-11 13:03:01                  False                 False
# 125452 2023-08-12 08:01:16                  False                 False
# 658467 2023-10-03 10:14:06                   True                 False
# 33601  2023-10-16 13:38:18                   True                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 303776      Singapore        None              NaN              NaN
# 330513        Ecuador        None              NaN              NaN
# 237202          India        None              NaN              NaN
# 539858          Sudan        None              NaN              NaN
# 618796    Netherlands        None              NaN              NaN
# 392419        Germany        None              NaN              NaN
# 657919          Italy        None              NaN              NaN
# 470055    Netherlands        None              NaN              NaN
# 65015   United States        None              NaN              NaN
# 24727           Spain        None              NaN              NaN
# 127391          Italy        None              NaN              NaN
# 448205          Sudan        hour              NaN             65.0
# 376863  United States        None              NaN              NaN
# 37390         Morocco        None              NaN              NaN
# 431027      Singapore        None              NaN              NaN
# 15138   United States        None              NaN              NaN
# 125452  United States        None              NaN              NaN
# 658467          India        None              NaN              NaN
# 33601          France        None              NaN              NaN
#
#                                              company_name  \
# 303776                             Gateway Search Pte Ltd
# 330513                                            Emprego
# 237202                                             Uplers
# 539858                               Tektree Systems Inc.
# 618796                                               imec
# 392419                                        ZEISS Group
# 657919                                      Adecco Italia
# 470055                                   Deutsche Bank AG
# 65015                                             Amentum
# 24727                                 HOLA CONSULTORES SL
# 127391                                        Deliveristo
# 448205                                     infinity quest
# 376863                                             Leidos
# 37390                             AllWays Health Partners
# 431027                                            Binance
# 15138                                      Central Health
# 125452                                                TRG
# 658467  EDCS :Expora Database Consulting Services Pvt....
# 33601                                   EMEA3 Recruitment
#
#                                                job_skills  \
# 303776                                          ['linux']
# 330513  ['java', 'python', 'aws', 'spark', 'hadoop', '...
# 237202  ['python', 'sql', 'nosql', 'aws', 'gcp', 'bigq...
# 539858  ['python', 'java', 'scala', 'perl', 'shell', '...
# 618796   ['python', 'matlab', 'r', 'c++', 'azure', 'git']
# 392419  ['t-sql', 'c#', 'powershell', 'azure', 'databr...
# 657919                                          ['excel']
# 470055                                          ['excel']
# 65015                   ['r', 'python', 'sql', 'tableau']
# 24727   ['python', 'sql', 'azure', 'aws', 'airflow', '...
# 127391  ['mongodb', 'mongodb', 'python', 'mysql', 'ela...
# 448205  ['python', 'sql', 'redshift', 'aws', 'azure', ...
# 376863                   ['tableau', 'power bi', 'excel']
# 37390                             ['sharepoint', 'excel']
# 431027  ['r', 'sql', 'nosql', 'vba', 'c++', 'java', 'p...
# 15138                                    ['sql', 'excel']
# 125452                ['python', 'r', 'alteryx', 'excel']
# 658467  ['python', 'databricks', 'azure', 'gcp', 'kube...
# 33601                 ['sql', 'azure', 'tableau', 'flow']
#
#                                           job_type_skills
# 303776                                  {'os': ['linux']}
# 330513  {'cloud': ['aws'], 'libraries': ['spark', 'had...
# 237202  {'analyst_tools': ['excel', 'word', 'powerpoin...
# 539858  {'async': ['jira', 'confluence'], 'cloud': ['b...
# 618796  {'cloud': ['azure'], 'other': ['git'], 'progra...
# 392419  {'analyst_tools': ['power bi'], 'cloud': ['azu...
# 657919                       {'analyst_tools': ['excel']}
# 470055                       {'analyst_tools': ['excel']}
# 65015   {'analyst_tools': ['tableau'], 'programming': ...
# 24727   {'cloud': ['azure', 'aws'], 'libraries': ['air...
# 127391  {'cloud': ['aws', 'bigquery'], 'databases': ['...
# 448205  {'cloud': ['redshift', 'aws', 'azure'], 'other...
# 376863  {'analyst_tools': ['tableau', 'power bi', 'exc...
# 37390          {'analyst_tools': ['sharepoint', 'excel']}
# 431027  {'analyst_tools': ['tableau'], 'programming': ...
# 15138   {'analyst_tools': ['excel'], 'programming': ['...
# 125452  {'analyst_tools': ['alteryx', 'excel'], 'progr...
# 658467  {'cloud': ['databricks', 'azure', 'gcp'], 'oth...
# 33601   {'analyst_tools': ['tableau'], 'cloud': ['azur...
